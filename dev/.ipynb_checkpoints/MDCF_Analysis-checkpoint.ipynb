# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.optimize import curve_fit

from dcf_python import *
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# <h3>This is where you load in the square region of your calculation</h3>

# %%
os.chdir("/Users/a16472/Desktop/dcf_python/testing")

# %%
data = fits.open("L10_0.65.fits")[0].data
data = data[::6, ::6]
y_cen = 260 / 6
x_cen = 180 / 6 
rad = 25

dt = data_cut(x_cen, y_cen, rad, data, show=True)

dr, dphi = cos_disp_calculations(dt, ds_scale=1)
multi_fit(dr, dphi, 'Region', ds_scale=1, outer_distance=21, fit0=13, fitf=21, show=True)
# Out:
# /Users/a16472/opt/anaconda3/lib/python3.8/site-packages/regions/shapes/rectangle.py:195: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   return Rectangle(xy=xy, width=width, height=height,
# /Users/a16472/Desktop/dcf_python/dev/dcf_python.py:96: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   delta_r = np.array(delta_r)
# /Users/a16472/Desktop/dcf_python/dev/dcf_python.py:97: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   delta_phi = np.array(delta_phi[:-1])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-48f65385d8f3> in <module>
#       8
#       9 dr, dphi = cos_disp_calculations(dt, ds_scale=1)
# ---> 10 multi_fit(dr, dphi, 'Region', ds_scale=1, outer_distance=21, fit0=13, fitf=21, show=True)
#
# ~/Desktop/dcf_python/dev/dcf_python.py in multi_fit(delta_r, delta_phi, ttl, ds_scale, outer_distance, fit0, fitf, show)
#     117
#     118     # Linear fit for the first two plots.
# --> 119     popt_linear, _ = curve_fit(linear_fit,  bin_edges_sq[fit0:fitf], 1-cos_disp_sq[start:end])
#     120
#     121     # Gaussian fit for the third plot.
#
# NameError: name 'start' is not defined
